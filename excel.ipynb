# %%
import pandas as pd
import numpy as np
from datetime import datetime

query_dtypes = {
    "PatientID": "string",
    "PatientName": "datetime64[ns]",
    "PatientBirthDate": "datetime64[ns]",
    "AccessionNumber": "string",
    "From": "datetime64[ns]",
    "Until": "datetime64[ns]",
    "Modality": "string",
    "SeriesDescription": "string",
    "SeriesNumber": "string",
    "Pseudonym": "string",
}

transfer_dtypes = {
    "PatientID": "string",
    "StudyInstanceUID": "string",
    "SeriesInstanceUID": "string",
    "Pseudonym": "string",
}

df = pd.read_excel('./samples/full_data_sheet.csv')
df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df.replace({np.nan: None, "": None}, inplace=True)

# df["PatientBirthDate"] = pd.to_datetime(df["PatientBirthDate"], errors="raise")

for idx, row in df.iterrows():
    print(row["PatientBirthDate"])
    date = pd.to_datetime(row["PatientBirthDate"], errors="raise")
    print(date)
    print(type(date))
    print("---")

# df["PatientBirthDate"] = pd.to_datetime(df["PatientBirthDate"], errors="raise")

# print(df)
    

# print(df["StudyDate"][0])

# print(df)
# for idx, row in df.iterrows():
#     print(df["PatientID"].dtype)
#     value = row.get("PatientID")
#     if not pd.isna(value) and value:
#         if isinstance(value, str):
#             value = value.strip()
#         print(value)
#     else:
#         print("Nope")

# df.fillna(None, inplace=True)
# print(df["FROM"][4])

# if pd.isna(df["PatientID"][0]):
#     print("yes")
# else:
#     print("no")

# print(df["PatientID"][0])

df.info(verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 25
#       5 query_dtypes = {
#       6     "PatientID": "string",
#       7     "PatientName": "datetime64[ns]",
#    (...)
#      15     "Pseudonym": "string",
#      16 }
#      18 transfer_dtypes = {
#      19     "PatientID": "string",
#      20     "StudyInstanceUID": "string",
#      21     "SeriesInstanceUID": "string",
#      22     "Pseudonym": "string",
#      23 }
# ---> 25 df = pd.read_excel('./samples/full_data_sheet.csv')
#      26 df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
#      27 df.replace({np.nan: None, "": None}, inplace=True)
#
# ...

# %%
import pandas as pd

df = pd.DataFrame([[1, 2], [3, 4]])

print(df[0][0])
# Out:
# 1

# %%
import pandas as pd
from datetime import datetime

df = pd.DataFrame([datetime(2022, 3, 4)])

print(df.info(verbose=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 136.0 bytes
# None

# %%
import pandas as pd

df = pd.DataFrame([{"PatientName": "foobar"}, {"PatientID": "alpha", "PatientName": "beta"}])


print(df)
# Out:
#   PatientName PatientID
# 0      foobar       NaN
# 1        beta     alpha
# Bad pipe message: %s [b"\xb7+gH\x82\xa4\x95r\\\xdf\xa6\xa8\xc4@`\x96\xbb\x08\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0", b'\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c']
# Bad pipe message: %s [b'\x92\xa7\xe3t\xadu\xb7c\x12\xbdo\x18A(\x0b\x1f\x80\x04\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07']
# ...
