# %%
import requests
from datetime import datetime

base_url = "http://localhost:8000/api/"

data = {
    "pacs_aet": "gepacs",
    "pacs_name": "GE PACS",
    "patient_id": "1234578",
    "year_of_birth": 1980,
    "gender": "M",
    "study_uid": "34343-34343-34343",
    "accession_number": "345348389",
    "study_description": "CT of the Thorax",
    "study_datetime": datetime(2000, 8, 10).isoformat(),
    "series_uid": "34343-676556-3343",
    "modalities": ["CT", "PET"],
    "instance_uid": "35858-384834-3843",
    "references": [],
    "content": "This is the report"
}

response = requests.post(base_url + "reports/", json=data)

print(response.json())
# Out:
# {'pathId': '/document/v1/radis/radis/docid/ZTQVxDMNgBuiUjwQisp8He', 'id': 'id:radis:radis::ZTQVxDMNgBuiUjwQisp8He'}

# %%
response = requests.get(base_url + "reports/CsVzJKQX2hSZszQk2k944Y")

print(response.json())
# Out:
# {'pathId': '/document/v1/radis/radis/docid/CsVzJKQX2hSZszQk2k944Y', 'id': 'id:radis:radis::CsVzJKQX2hSZszQk2k944Y', 'fields': {'pacs_name': 'GE PACS', 'modalities': ['CT', 'PET'], 'series_uid': '34343-676556-3343', 'patient_id': '1234578', 'content': 'This is the report', 'instance_uid': '35858-384834-3843', 'study_description': 'CT of the Thorax', 'study_uid': '34343-34343-34343', 'accession_number': '345348389', 'pacs_aet': 'gepacs', 'study_datetime': 965858400}}
