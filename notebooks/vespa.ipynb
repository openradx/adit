# %%
from vespa.application import Vespa
import pandas as pd
from requests import HTTPError

app = Vespa("http://localhost", 8080)

print(app.get_application_status())

try:
    response = app.get_data(schema="report", data_id="abc")
    print(response.get_json())
except HTTPError as err:
    print(err.response.status_code)
    print("Document not found.")

data = {
    "organizations": ["allrad"],
    "pacs_aet": "foobar",
    "pacs_name": "foobar",
    "patient_id": "foobar",
    "year_of_birth": 1950,
    "gender": "M",
    "study_uid": "foobar",
    "accession_number": "foobar",
    "study_description": "foobar",
    "study_datetime": 1234,
    "series_uid": "foobar",
    "modalities": ["CT", "PET"],
    "instance_uid": "foobar",
    "references": ["foobar"],
    "body": "foo bar mar",
}

result = app.feed_data_point(schema="report", data_id="abc", fields=data)
print(result.get_json())

# %%
from vespa.application import Vespa
import pandas as pd
from requests import HTTPError

client = Vespa("http://localhost", 8080)

print(client.get_application_status())

results = client.query({
    "yql": "select body from sources * where true",
    "hits": 2
})

print(results.number_documents_retrieved)

results.hits

# %%
from vespa.application import Vespa
import pandas as pd
from requests import HTTPError

client = Vespa("http://localhost", 8080)

print(client.get_application_status())

results = client.query(body={
    "yql": "select * from report where userQuery()",
    "query": "pain",
    "type": "web",
    "hits": 10,
})

print(results.number_documents_retrieved)

results.get_json()
# Out:
# <Response [200]>
# 81
# {'root': {'id': 'toplevel',
#   'relevance': 1.0,
#   'fields': {'totalCount': 81},
#   'coverage': {'coverage': 100,
#    'documents': 100,
#    'full': True,
#    'nodes': 1,
#    'results': 1,
#    'resultsFull': 1},
#   'children': [{'id': 'index:radis_content/0/eeebc4d55d1542ac79713301',
#     'relevance': 0.3693024005262521,
#     'source': 'radis_content',
#     'fields': {'body': "<sep />Clinical History: Lower back <hi>pain</hi> and radiating leg <hi>pain</hi>\n\n<sep />evaluate the cause of the patient's lower back <hi>pain</hi> and radiating leg <hi>pain</hi>. Additional<sep />"}},
#    {'id': 'index:radis_content/0/549a18724f0eb672eb407328',
#     'relevance': 0.35301082516825283,
#     'source': 'radis_content',
#     'fields': {'body': "<sep />Clinical History: Lower back <hi>pain</hi> and radiating leg <hi>pain</hi>\n\n<sep />contributing to the patient's lower back <hi>pain</hi> and radiating leg <hi>pain</hi>.\n\nClinical<sep />"}},
#    {'id': 'index:radis_content/0/1bda1059e0ad7b01641006d0',
#     'relevance': 0.339310829797242,
#     'source': 'radis_content',
#     'fields': {'body': '<sep />Clinical History: Right hip <hi>pain</hi> and limited mobility\n\nImaging Technique<sep />hip osteoarthritis. Options such as <hi>pain</hi> management, joint injections, physical<sep />'}},
#    {'id': 'index:radis_content/0/abe8963c13a60f57ba9b18ec',
#     'relevance': 0.339064712235196,
#     'source': 'radis_content',
#     'fields': {'body': "<sep />History: Right shoulder <hi>pain</hi> and limited range of motion\n\nImaging<sep /> that the patient's right shoulder <hi>pain</hi> and limited range of motion may be related<sep />"}},
#    {'id': 'index:radis_content/0/e700ef91250bdc3dfb51715d',
#     'relevance': 0.3361700247821368,
#     'source': 'radis_content',
#     'fields': {'body': '<sep />History: Chronic low back <hi>pain</hi> and radiculopathy\n\nImaging <sep />referring physician to discuss appropriate <hi>pain</hi> management strategies, physical therapy<sep />'}},
#    {'id': 'index:radis_content/0/7ae0b904d47d04547d9cce38',
#     'relevance': 0.33489587066344684,
#     'source': 'radis_content',
#     'fields': {'body': "<sep />Clinical History: Right hip <hi>pain</hi> and limited range of motion\n\nImaging<sep />findings correlate with the patient's right hip <hi>pain</hi> and limited range of motion.\n2. The<sep />"}},
#    {'id': 'index:radis_content/0/6bc9eda7099e977d18cd142f',
#     'relevance': 0.32416082000520197,
#     'source': 'radis_content',
#     'fields': {'body': "<sep />Clinical History: Chest <hi>pain</hi>, shortness of breath\n\nImaging<sep />determine the cause of the patient's chest <hi>pain</hi> and shortness of breath."}},
#    {'id': 'index:radis_content/0/edfbc78f647f8707d715522f',
#     'relevance': 0.32151183410155976,
#     'source': 'radis_content',
#     'fields': {'body': "<sep />Clinical History: Left hip <hi>pain</hi> and limited range of motion\n\nImaging<sep />results do not explain the patient's left hip <hi>pain</hi> and limited range of motion."}},
#    {'id': 'index:radis_content/0/b94f91a3a80ee2d859bb85fd',
#     'relevance': 0.32093340245310314,
#     'source': 'radis_content',
#     'fields': {'body': "<sep />Clinical History: Abdominal <hi>pain</hi>\n\nImaging Technique<sep />No specific cause for the patient's abdominal <hi>pain</hi> is identified on the ultrasound<sep />"}},
#    {'id': 'index:radis_content/0/4c24e63d301cef39c0b75bc7',
#     'relevance': 0.3206384335769912,
#     'source': 'radis_content',
#     'fields': {'body': "<sep />Clinical History: Chest <hi>pain</hi> and shortness of breath\n\n<sep />unable to explain the patient's current chest <hi>pain</hi> and shortness of breath."}}]}}
