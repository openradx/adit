# %%
from vespa.application import Vespa
import pandas as pd
from requests import HTTPError

app = Vespa("http://localhost", 8080)

print(app.get_application_status())

try:
    response = app.get_data(schema="report", data_id="abc")
    print(response.get_json())
except HTTPError as err:
    print(err.response.status_code)
    print("Document not found.")

data = {
    "organizations": ["allrad"],
    "pacs_aet": "foobar",
    "pacs_name": "foobar",
    "patient_id": "foobar",
    "year_of_birth": 1950,
    "gender": "M",
    "study_uid": "foobar",
    "accession_number": "foobar",
    "study_description": "foobar",
    "study_datetime": 1234,
    "series_uid": "foobar",
    "modalities": ["CT", "PET"],
    "instance_uid": "foobar",
    "references": ["foobar"],
    "content": "foobari",
}

result = app.feed_data_point(schema="report", data_id="abc", fields=data)
print(result.get_json())
# Out:
# <Response [200]>
# {'pathId': '/document/v1/report/report/docid/abc', 'id': 'id:report:report::abc', 'fields': {'pacs_name': 'foobar', 'modalities': ['CT', 'PET'], 'series_uid': 'foobar', 'gender': 'M', 'patient_id': 'foobar', 'content': 'foobari', 'references': ['foobar'], 'instance_uid': 'foobar', 'study_description': 'foobar', 'year_of_birth': 1950, 'study_uid': 'foobar', 'accession_number': 'foobar', 'organizations': ['allrad'], 'pacs_aet': 'foobar', 'study_datetime': 1234}}
# {'pathId': '/document/v1/report/report/docid/abc', 'id': 'id:report:report::abc'}

# %%
from vespa.application import Vespa
import pandas as pd
from requests import HTTPError

client = Vespa("http://localhost", 8080)

print(client.get_application_status())

results = client.query({
    "yql": "select * from sources * where true",
    "hits": 2
})

print(results.number_documents_retrieved)

results.hits[0]["fields"]
# Out:
# <Response [200]>
# 101
# {'sddocname': 'report',
#  'documentid': 'id:report:report::kNB63UV4NiW2Y2f5NUVkJj',
#  'pacs_name': 'Synapse',
#  'patient_id': '91555281',
#  'year_of_birth': 2004,
#  'gender': 'M',
#  'accession_number': '3086953173425',
#  'study_description': 'List hour life people tree cost require.',
#  'study_datetime': 1576103117,
#  'modalities': ['US']}

# %%
import tempfile

with tempfile.TemporaryDirectory() as tmpdirname:
    print(tmpdirname)
# Out:
# /tmp/tmpvq48wvl4
